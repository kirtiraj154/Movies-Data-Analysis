# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
os.chdir("D:\\")

# %%
df=pd.read_excel("Assignment_yuvi.xls")

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
df.tail(10)
# Out:
#                            name     rating   genre  year  \
# 7658  Black Wall Street Burning          R   Drama  2020
# 7659                  I Am Fear  Not Rated  Horror  2020
# 7660           Aloha Surf Hotel        NaN  Comedy  2020
# 7661           Love by Drowning          R   Drama  2020
# 7662              The Robinsons        NaN  Action  2020
# 7663               More to Life        NaN   Drama  2020
# 7664                Dream Round        NaN  Comedy  2020
# 7665              Saving Mbango        NaN   Drama  2020
# 7666               It's Just Us        NaN   Drama  2020
# 7667                  Tee em el        NaN  Horror  2020
#
#                                released  score  votes            director  \
# 7658   February 7, 2020 (United States)    6.6   35.0        Marcus Brown
# 7659      March 3, 2020 (United States)    3.4  447.0       Kevin Shulman
# 7660   November 5, 2020 (United States)    7.1   14.0  Stefan C. Schaefer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.describe().transpose()
# Out:
#           count          mean           std     min         25%         50%  \
# year     7668.0  2.000405e+03  1.115351e+01  1980.0      1991.0      2000.0
# score    7665.0  6.390411e+00  9.688416e-01     1.9         5.8         6.5
# votes    7665.0  8.810850e+04  1.633238e+05     7.0      9100.0     33000.0
# budget   5497.0  3.558988e+07  4.145730e+07  3000.0  10000000.0  20500000.0
# gross    7479.0  7.850054e+07  1.657251e+08   309.0   4532055.5  20205757.0
# runtime  7664.0  1.072616e+02  1.858125e+01    55.0        95.0       104.0
#
#                 75%           max
# year         2010.0  2.020000e+03
# score           7.1  9.300000e+00
# votes       93000.0  2.400000e+06
# budget   45000000.0  3.560000e+08
# gross    76016691.5  2.847246e+09
# runtime       116.0  3.660000e+02

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df1.groupby('year')['votes'].mean().sort_values(ascending=False)
# Out:
# year
# 2013    194310.559006
# 2014    186797.546012
# 2012    179525.308642
# 2011    172906.250000
# 2010    162330.487805
# 2008    159716.374269
# 2004    149526.721519
# 2007    148943.949045
# 2017    145469.172932
# 2009    145441.520468
# 2016    145153.164557
# 2006    143533.742331
# 2015    143071.794872
# 2020    137962.500000
# 2003    130798.113208
# 2019    127360.132743
# 2005    126581.176471
# 2001    124598.780488
# 1999    119779.629630
# 2002    112873.410405
# 2018    112353.846154
# 1994    104921.875000
# 2000    101550.617284
# 1995     97495.355072
# 1997     96183.892617
# 1998     96060.810811
# 1980     94896.625000
# 1990     67803.603604
# 1993     64444.285714
# 1996     62775.694444
# 1984     60880.613636
# 1991     58049.557522
# 1982     56334.098592
# 1992     55249.618321
# 1985     52972.389474
# 1989     52343.069565
# 1987     51632.701923
# 1986     49763.525253
# 1988     46580.330769
# 1983     44748.614458
# 1981     42848.126984
# ...

# %%
plt.figure(figsize=(18,18))
sns.barplot(x='year',y='votes',data=df1)
plt.title("Votes By Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df1.groupby('year')['gross'].mean().sort_values(ascending=False)
# Out:
# year
# 2020    2.841127e+08
# 2019    2.450678e+08
# 2017    2.081188e+08
# 2018    1.927169e+08
# 2016    1.762504e+08
# 2015    1.680571e+08
# 2014    1.607302e+08
# 2013    1.596252e+08
# 2012    1.552328e+08
# 2011    1.498019e+08
# 2010    1.328565e+08
# 2009    1.323977e+08
# 2007    1.226607e+08
# 2008    1.223059e+08
# 2004    1.147133e+08
# 2006    1.096732e+08
# 2003    1.081816e+08
# 2005    1.022235e+08
# 2002    9.503332e+07
# 2001    9.375281e+07
# 1997    8.501497e+07
# 1999    8.161126e+07
# 2000    8.136492e+07
# 1998    7.335474e+07
# 1994    6.527944e+07
# 1996    6.301720e+07
# 1995    6.183214e+07
# 1990    5.477707e+07
# 1993    5.188667e+07
# 1992    4.950053e+07
# 1991    4.898839e+07
# 1989    4.846537e+07
# 1980    4.429196e+07
# 1982    3.804393e+07
# 1985    3.403673e+07
# 1984    3.396954e+07
# 1988    3.347553e+07
# 1987    3.228688e+07
# 1986    2.964930e+07
# 1981    2.918663e+07
# 1983    2.796927e+07
# Name: gross, dtype: float64

# %%
plt.figure(figsize=(18,18))
sns.barplot(x='year',y='gross',data=df1)
plt.title("Gross By Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df1.groupby('director')['score'].mean().sort_values(ascending=False)
# Out:
# director
# Roberto Benigni       8.600
# Tony Kaye             8.500
# Nadine Labaki         8.400
# Bob Persichetti       8.400
# Sergio Leone          8.400
#                       ...
# Jason Friedberg       2.625
# Rod Amateau           2.600
# Roger Christian       2.500
# Farhad Mann           2.500
# Vondie Curtis-Hall    2.300
# Name: score, Length: 2063, dtype: float64

# %%
top10_len=df1.nlargest(10,"runtime")[["name","runtime"]]\
.set_index('name')

# %%
top10_len
# Out:
#                                                runtime
# name
# Gettysburg                                       271.0
# Hamlet                                           242.0
# Once Upon a Time in America                      229.0
# Heaven's Gate                                    219.0
# Gods and Generals                                219.0
# Kabhi Khushi Kabhie Gham...                      210.0
# The Irishman                                     209.0
# Malcolm X                                        202.0
# The Lord of the Rings: The Return of the King    201.0
# Reds                                             195.0

# %%
sns.barplot(x='runtime',y=top10_len.index,data=top10_len)
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='name'>

# %%
df1['year'].value_counts()
# Out:
# 2002    173
# 2009    171
# 2008    171
# 2005    170
# 2001    164
# 2010    164
# 2014    163
# 2006    163
# 2000    162
# 2012    162
# 1999    162
# 2013    161
# 2011    160
# 2003    159
# 2016    158
# 2004    158
# 2007    157
# 2015    156
# 1997    149
# 1998    148
# 1996    144
# 2018    143
# 1993    140
# 1995    138
# 2017    133
# 1992    131
# 1988    130
# 1994    128
# 1989    115
# 2019    113
# 1991    113
# 1990    111
# 1987    104
# 1986     99
# 1985     95
# 1984     88
# 1983     83
# 1982     71
# 1981     63
# 1980     40
# 2020      8
# Name: year, dtype: int64

# %%
plt.figure(figsize=(18,18))
sns.countplot(x='year',data=df1)
plt.title("Number of Movies Per Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df1[df1['gross'].max()==df1['gross']]['name']
# Out:
# 5445    Avatar
# Name: name, dtype: object

# %%
top10_len=df1.nlargest(10,"score")[["name","score",'director']]\
.set_index('name')

# %%
top10_len
# Out:
#                                                    score           director
# name
# The Shawshank Redemption                             9.3     Frank Darabont
# The Dark Knight                                      9.0  Christopher Nolan
# Schindler's List                                     8.9   Steven Spielberg
# Pulp Fiction                                         8.9  Quentin Tarantino
# The Lord of the Rings: The Return of the King        8.9      Peter Jackson
# Forrest Gump                                         8.8    Robert Zemeckis
# Fight Club                                           8.8      David Fincher
# The Lord of the Rings: The Fellowship of the Ring    8.8      Peter Jackson
# Inception                                            8.8  Christopher Nolan
# Star Wars: Episode V - The Empire Strikes Back       8.7     Irvin Kershner

# %%
sns.barplot(x='score',y=top10_len.index,data=top10_len,hue='director',
            dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
top_10=df1.nlargest(10,'gross')[['name','gross']].\
set_index('name')

# %%
top_10
# Out:
#                                                    gross
# name
# Avatar                                      2.847246e+09
# Avengers: Endgame                           2.797501e+09
# Titanic                                     2.201647e+09
# Star Wars: Episode VII - The Force Awakens  2.069522e+09
# Avengers: Infinity War                      2.048360e+09
# The Lion King                               1.670728e+09
# Jurassic World                              1.670516e+09
# The Avengers                                1.518816e+09
# Furious 7                                   1.515341e+09
# Frozen II                                   1.450027e+09

# %%
sns.barplot(x='gross',y=top_10.index,data=top_10)
plt.title("Top 10 Highest Gross Movie Titles")
plt.show()

# %%
df1.groupby('year')['score'].mean().sort_values(ascending=False)
# Out:
# year
# 2020    6.612500
# 2013    6.587578
# 2016    6.574684
# 2014    6.558896
# 2017    6.511278
# 1980    6.510000
# 2019    6.507080
# 2015    6.494872
# 1982    6.483099
# 1995    6.471014
# 2018    6.458741
# 1985    6.453684
# 2012    6.442593
# 2009    6.438596
# 2007    6.431210
# 2011    6.428750
# 1992    6.424427
# 1999    6.416667
# 1998    6.416216
# 1993    6.400714
# 1984    6.398864
# 2006    6.394479
# 1988    6.381538
# 2010    6.378049
# 2008    6.376023
# 2004    6.362025
# 1990    6.357658
# 1989    6.346957
# 1991    6.338938
# 2001    6.335976
# 2005    6.335882
# 1981    6.328571
# 1994    6.317188
# 1997    6.300671
# 1986    6.296970
# 2002    6.282081
# 2003    6.256604
# 1996    6.247917
# 2000    6.245679
# 1987    6.217308
# 1983    6.067470
# Name: score, dtype: float64

# %%
sns.scatterplot(x='score',y='gross',data=df1)
# Out:
# <AxesSubplot:xlabel='score', ylabel='gross'>

# %%
def score(score):
    if score>=7.0:
        return "Excellent"
    elif score>=6.0:
        return "Good"
    else:
        return "Average"

# %%
df1['score_all']=df1['score'].apply(score)
# Out:
# C:\Users\KIRTI RAJ PRADHAN\AppData\Local\Temp\ipykernel_14212\4113248446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['score_all']=df1['score'].apply(score)

# %%
df1.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df1['genre'].dtype
# Out:
# dtype('O')

# %%
df1[df1['genre'].str.contains('Action',case=False)]
# Out:
#                                                 name     rating   genre  year  \
# 2     Star Wars: Episode V - The Empire Strikes Back         PG  Action  1980
# 6                                 The Blues Brothers          R  Action  1980
# 8                                        Superman II         PG  Action  1980
# 10                             Any Which Way You Can         PG  Action  1980
# 22                               The Final Countdown         PG  Action  1980
# ...                                              ...        ...     ...   ...
# 7643                                           Tenet      PG-13  Action  2020
# 7645                                   Birds of Prey          R  Action  2020
# 7648                               Bad Boys for Life          R  Action  2020
# 7649                              Sonic the Hedgehog         PG  Action  2020
# 7652                               The Eight Hundred  Not Rated  Action  2020
#
# ...

# %%
len(df1[df1['genre'].str.contains('Action',case=False)])
# Out:
# 1415

# %%
df1['genre']
# Out:
# 0           Drama
# 1       Adventure
# 2          Action
# 3          Comedy
# 4          Comedy
#           ...
# 7648       Action
# 7649       Action
# 7650    Adventure
# 7651    Adventure
# 7652       Action
# Name: genre, Length: 5421, dtype: object

# %%
list1=[]
for value in df1['genre']:
    list1.append(value.split(','))

# %%
list1
# Out:
# [['Drama'],
#  ['Adventure'],
#  ['Action'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Horror'],
#  ['Action'],
#  ['Biography'],
#  ['Action'],
#  ['Biography'],
#  ['Action'],
#  ['Adventure'],
#  ['Adventure'],
#  ['Drama'],
#  ['Crime'],
#  ['Drama'],
#  ['Comedy'],
#  ['Horror'],
#  ['Crime'],
#  ['Adventure'],
#  ['Action'],
#  ['Fantasy'],
#  ['Crime'],
#  ['Crime'],
#  ['Drama'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Action'],
#  ['Action'],
#  ['Action'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Action'],
#  ['Action'],
#  ['Comedy'],
#  ['Action'],
#  ['Adventure'],
#  ['Comedy'],
#  ['Drama'],
#  ['Action'],
#  ['Comedy'],
#  ['Action'],
#  ['Horror'],
#  ['Comedy'],
#  ['Crime'],
#  ['Action'],
#  ['Adventure'],
#  ['Action'],
#  ['Comedy'],
#  ['Action'],
#  ['Action'],
#  ['Adventure'],
#  ['Horror'],
#  ['Action'],
#  ['Horror'],
#  ['Drama'],
#  ['Biography'],
#  ['Animation'],
#  ['Biography'],
#  ['Drama'],
#  ['Adventure'],
#  ['Drama'],
#  ['Comedy'],
# ...

# %%
one_d=[]
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# ['Drama',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Biography',
#  'Action',
#  'Biography',
#  'Action',
#  'Adventure',
#  'Adventure',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Crime',
#  'Adventure',
#  'Action',
#  'Fantasy',
#  'Crime',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Action',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Action',
#  'Horror',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Action',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Action',
#  'Horror',
#  'Drama',
#  'Biography',
#  'Animation',
#  'Biography',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Crime',
#  'Adventure',
#  'Horror',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Horror',
# ...

# %%
unit_list=[]
for item in one_d:
    if item not in unit_list:
        unit_list.append(item)

# %%
unit_list
# Out:
# ['Drama',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Horror',
#  'Biography',
#  'Crime',
#  'Fantasy',
#  'Animation',
#  'Family',
#  'Western',
#  'Sci-Fi',
#  'Romance',
#  'Thriller',
#  'Mystery']

# %%
one_d=[]
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 863,
#          'Adventure': 327,
#          'Action': 1415,
#          'Comedy': 1496,
#          'Horror': 251,
#          'Biography': 311,
#          'Crime': 399,
#          'Fantasy': 41,
#          'Animation': 277,
#          'Family': 4,
#          'Western': 2,
#          'Sci-Fi': 6,
#          'Romance': 5,
#          'Thriller': 7,
#          'Mystery': 17})
